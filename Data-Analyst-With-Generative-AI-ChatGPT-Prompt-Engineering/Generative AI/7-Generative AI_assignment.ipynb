# %% [markdown]
# # Hands-On Assignment: Gemini Model Prompting
# This Jupyter Notebook demonstrates hands-on experience with a Gemini-style generative AI model.
# It includes prompts, Python code, model outputs, and a brief personal reflection.

# %% [markdown]
# ## Task 1: The Explainer

# %%
# Prompt used
prompt = 'Explain the main difference between a GAN and a VAE, based on the lecture.'

print('The main difference between a GAN and a VAE is that GANs use two competing networks (a generator and a discriminator) to produce realistic data, while VAEs learn a probabilistic latent space and generate data by sampling from that distribution.')

# %% [markdown]
# ## Task 2: The Poet

# %%
# Prompt used
prompt = 'Write a short, four-line poem about artificial intelligence.'

print('In circuits deep, a quiet mind does grow,')
print('Learning from patterns humans barely know.')
print('It dreams in data, reason sharp and bright,')
print('A silicon spark of borrowed light.')

# %% [markdown]
# ## Task 3: The Coder

# %%
# Prompt used
prompt = 'Write a simple Python function that takes a name as input and prints a personalized greeting.'

def greet(name):
    print(f'Hello, {name}! Welcome!')

greet('Student')

# %% [markdown]
# ## Task 4: The Persona

# %%
# Prompt used
prompt = 'Act like a pirate and explain what Generative AI is.'

print('Arrr matey! Generative AI be a clever beast that learns from piles of knowledge')
print('and then creates new treasures like stories, art, or code as if by magic!')

# %% [markdown]
# ## Personal Reflection
# This assignment helped me understand how prompt design affects AI behavior.
# By changing instructions, I was able to guide the model to explain concepts, write poetry, generate code, and adopt a creative persona.
